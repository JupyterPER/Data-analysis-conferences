# %% [markdown]
# **Authors:** <font color=brown>Jozef Hanč & his students</font>  <br>
# [Faculty of Science](https://www.upjs.sk/en/faculty-of-science/?prefferedLang=EN) *P.J. Šafárik University in Košice, Slovakia* <br>
# email: [jozef.hanc@upjs.sk](mailto:jozef.hanc@upjs.sk)
# **Document:** Data analysis for AIP publishing house
# **Date**: July 2022

# %% [markdown]
# # Contributions from AIP web

# %% [markdown]
# ## parameters

# %%
# conference = 'didfyz2021'
# pubdate = 'May 2022'
# invited = 5
# access = 'No Access'

# %% [markdown]
# ## processing

# %%
f = open(f'../{conference}.txt', "r")
text = f.read()
f.close()

# %%
rozd = '''
SHOW ABSTRACT 
PDFE-READERADD TO FAVORITESSHAREEXPORT CITATION
'''+access+pubdate+'\n'

rozd
# Out:
# '\nSHOW ABSTRACT \nPDFE-READERADD TO FAVORITESSHAREEXPORT CITATION\nNo AccessMay 2022\n'

# %%
dk = DF(list(text.split(rozd)), colname='title')
show_colwidth(dk, col_width=1000)
# Out:
#                                                                                                                                                                                                                                                                                              title
# 0                                                                 Opportunities and pitfalls of physical experimentation in distance learning\nStanislav Holec, Miriam Spodniaková Pfefferová and Martin Hruška\nAIP Conference Proceedings 2458, 020001 (2022); https://doi.org/10.1063/5.0078376
# 1                                                                                                Digital transformation as a challenge for physics education\nMarián Kireš, Dušan Šveda and Veronika Hubeňáková\nAIP Conference Proceedings 2458, 020002 (2022); https://doi.org/10.1063/5.0078614
# ...

# %%
dk = dk.title.str.split('\n', expand=True).iloc[:,:3].rename(columns = {0:'title',1:'authors',2:'journal'})
show_allrowscols(dk, fullcolwidth=True)
# Out:
#                                                                                                                                                  title  \
# 0                                                                          Opportunities and pitfalls of physical experimentation in distance learning
# 1                                                                                          Digital transformation as a challenge for physics education
# 2                                                                                    TIPS for active learning approach in distance learning conditions
# 3                                               Remote teaching at the Pedagogical University in Krakow from the perspective of students and lecturers
# 4                                                                                               Video experiments in initial primary teacher education
# ...

# %%
dk['authorslist'] = dk['authors'].str.replace(' and ',', ').str.split(', ')

# %% [markdown]
# ## invited papers

# %%
dk['type'] = 'other'
dk.loc[:invited-1, 'type'] = 'invited'
show_allrowscols(dk, fullcolwidth=True)
# Out:
#                                                                                                                                                  title  \
# 0                                                                          Opportunities and pitfalls of physical experimentation in distance learning
# 1                                                                                          Digital transformation as a challenge for physics education
# 2                                                                                    TIPS for active learning approach in distance learning conditions
# 3                                               Remote teaching at the Pedagogical University in Krakow from the perspective of students and lecturers
# 4                                                                                               Video experiments in initial primary teacher education
# ...
