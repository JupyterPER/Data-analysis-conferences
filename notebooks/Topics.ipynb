# %% [markdown]
# **Authors:** <font color=brown>Jozef Hanč & his students</font>  <br>
# [Faculty of Science](https://www.upjs.sk/en/faculty-of-science/?prefferedLang=EN) *P.J. Šafárik University in Košice, Slovakia* <br>
# email: [jozef.hanc@upjs.sk](mailto:jozef.hanc@upjs.sk)
# **Document:** Data analysis for AIP publishing house
# **Date**: July 2022

# %% [markdown]
# # Topics for contributions

# %% [markdown]
# ## parameters

# %%
# conference = 'didfyz2019'
# pubdate = 'September 2019'
# invited = 4
# access = 'No Access'

# from ast import literal_eval
# dk = pd.read_excel('../'+conference+'-scopus.xlsx', index_col=0, sheet_name='contributions')
# dk['authorslist'] = dk['authorslist'].apply(literal_eval)
# dk
# Out:
#                                                 title  \
# 0   Views of physics teachers concerning possible ...
# 1   Effective individual work of pupils within phy...
# 2   The way of coordination - Inquiry based activi...
# 3   Inquiry-based science education as a support o...
# 4   Analysis of biophysical knowledge of medical a...
# 5   Home experiments - A way to increase the inter...
# 6   Selection of experiments with respect to age o...
# 7   Experiments as a basis of informal in-service ...
# 8   Interdisciplinary approach for the education o...
# 9   Images of atoms in physics textbooks for lower...
# 10  The impact of experiments in physics lessons –...
# 11  Formation of the natural-science image of the ...
# 12  Investigating properties of the periodic motio...
# 13  The impact of inquiry-based activities on the ...
# 14  Modeling activities in the framework of an int...
# 15  Scientific conceptual map as a compliance tool...
# ...

# %% [markdown]
# ## basic processing

# %%
dt = pd.read_excel('../'+conference+'-topics.xlsx')

# %%
df = pd.merge(dk, dt, on='title', how='outer').rename(columns={'keywords':'topic'})
df
# Out:
#                                                 title  \
# 0   Views of physics teachers concerning possible ...
# 1   Effective individual work of pupils within phy...
# 2   The way of coordination - Inquiry based activi...
# 3   Inquiry-based science education as a support o...
# 4   Analysis of biophysical knowledge of medical a...
# 5   Home experiments - A way to increase the inter...
# 6   Selection of experiments with respect to age o...
# 7   Experiments as a basis of informal in-service ...
# 8   Interdisciplinary approach for the education o...
# 9   Images of atoms in physics textbooks for lower...
# 10  The impact of experiments in physics lessons –...
# 11  Formation of the natural-science image of the ...
# 12  Investigating properties of the periodic motio...
# 13  The impact of inquiry-based activities on the ...
# 14  Modeling activities in the framework of an int...
# 15  Scientific conceptual map as a compliance tool...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        45 non-null     object
#  1   authors      45 non-null     object
#  2   journal      45 non-null     object
#  3   authorslist  45 non-null     object
#  4   type         45 non-null     object
#  5   abstract     45 non-null     object
#  6   topic        45 non-null     object
#  7   subject      45 non-null     object
# dtypes: object(8)
# memory usage: 3.2+ KB

# %%
df.topic = np_clean_str(df.topic)
df.topic.unique()
# Out:
# array(["teacher's training", 'inquiry skills, literacy', 'other',
#        'labs, experiments', 'concepts, misconceptions',
#        'digital technology', 'projects', 'history', 'informal education',
#        'innovative curriculum'], dtype=object)

# %%
# check consistency
shape = df.shape[0] == dk.shape[0]
title = (df.title == dk.title).all()
shape, title
# Out:
# (True, True)

# %%
dk = df.copy()
show_allrowscols(dk, fullcolwidth=True)
# Out:
#                                                                                                                                    title  \
# 0                           Views of physics teachers concerning possible reform of framework educational programs in the Czech Republic
# 1                                     Effective individual work of pupils within physics education in the light of the learning sciences
# 2                                                The way of coordination - Inquiry based activities, development of cognitive operations
# 3                                                                       Inquiry-based science education as a support of school readiness
# 4                         Analysis of biophysical knowledge of medical and urgent health care students at the beginning of their studies
# 5                          Home experiments - A way to increase the interest of young people in physics, technology and natural sciences
# ...
